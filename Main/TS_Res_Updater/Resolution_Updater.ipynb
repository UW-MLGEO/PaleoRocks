# %% [markdown]
# # Thin Section Resolution Updater
# Input thin section image folders here to decrease pixel resolution for model analyses.

# %% [markdown]
# ## Dependencies

# %%
# %pip install Pillow
from PIL import Image
import os
# Out:
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/cse160/lib/python3.13/site-packages (11.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Thin Section Images
# 1. Add thin section images to a **Input_Images** folder on your desktop.
#
# 2. Change the file path to reflect your local folder location.
#
# 3. Option to update **scale** factor (1.0 = Highest Resolution, 0 = Lowest Resolution).

# %%
# Define Folder Paths:: 
input_folder = "/Users/sophiarobillard/Desktop/Input_Images"  # Path to the input images
output_folder = "/Users/sophiarobillard/Desktop/Output_Images"  # Path to save the output images

scale = 0.1  # Scale factor (0.5 for 50% reduction)

# Verify that the input folder exists
if not os.path.exists(input_folder):
    print(f"Error: The input folder '{input_folder}' does not exist.")
else:
    print(f"Input folder found: {input_folder}")
# Out:
# Input folder found: /Users/sophiarobillard/Desktop/Input_Images

# %% [markdown]
# ## Lower Image Resolution

# %%
# Function to lower the resolution of an image
def lower_resolution(input_path, output_path, scale):
    # Open the image
   with Image.open(input_path) as img:
    # Calculate new dimensions
    new_width = int(img.width * scale)
    new_height = int(img.height * scale)
    
    # Resize the image
    img_resized = img.resize((new_width, new_height), Image.Resampling.NEAREST)
    
    # Save the resized image
    img_resized.save(output_path)
    print(f"Saved at {output_path} with resolution {new_width}x{new_height}")

# Loop through all files in Input_Images folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"resized_{filename}")
    # Call the function to lower the resolution
    lower_resolution(input_path, output_path, scale)
print("All images processed.")
# Out:
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_66.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_44.9c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_78.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_61.0e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_26.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_26.0e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_37.5.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_61.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_48.4.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_7.4.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_50.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_72.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_44.9a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_66.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_101.0(1).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_57.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_78.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_61.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_74.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_26.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_73.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_26.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_54.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_72.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_94.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_61.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_57.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_66.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_66.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_57.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_78.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_74.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_72.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_26.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_73.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_94.0(1).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_72.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_61.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_64.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_62.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_19.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_77.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_22.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_46.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_76.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_89.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_41.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_58.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_14.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_14.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_41.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_70.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_46.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_22.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_62.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_98.0(1).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_74.0a(2).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_11.2e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_16.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_64.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_19.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_77.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_46.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_0.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_76.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_58.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_14.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_41.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_70.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_22.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_62.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_64.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_11.2d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_16.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_0.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_14.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_41.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_22.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_62.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_11.2a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_16.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_11.2c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_81.2.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_0.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_0.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_11.2b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_16.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_26.0e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_37.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_45.6a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_30.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_29.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_5.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_9.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_18.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_0.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_59.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_0.0e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_9.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_37.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_26.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_101.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_30.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_45.6b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_7.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_9.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_19.2d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_59.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_59.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_0.0f.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_39.6.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_19.2e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_69.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_101.1.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_29.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_41.6.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_37.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_26.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_74.0a(1).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_29.0e.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_9.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_81.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_18.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_0.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_80.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_86.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_0.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opc_18.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_81.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_29.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_26.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_37.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_8.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_44.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_29.0f.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_81.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_7.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_19.2b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_80.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_86.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_19.2c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_7.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_18.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_29.0g.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_98.0(2).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_26.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_90.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_0.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_0.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_82.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_85.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_82.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_53.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_19.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_84.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_0.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_90.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_101.0(2).JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_98.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_90.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_0.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_53.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_82.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_19.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_97.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_85.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_19.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_84.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_15.4b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_2.5b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_26.0c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_0.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opd_94.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_26.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_2.5c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_93.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_15.4c.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opb_15.4a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_2.0b.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_2.5a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_51.0.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_opf_19.0d.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_26.0a.JPG with resolution 600x400
# Saved at /Users/sophiarobillard/Desktop/Output_Images/resized_ope_34.0a.JPG with resolution 600x400
# All images processed.
